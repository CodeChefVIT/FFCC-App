# %%
import numpy as np


import nltk
    
nltk.download('vader_lexicon')

import pandas as pd

df = pd.read_csv(r'C:\Users\ADITYA\Desktop\data$ET.csv')
df.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ADITYA\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#    Id Which school does the teacher belongs to                NAME  \
# 0   5                                     SMEC           ANIL P.M.
# 1   6                                     SMEC           ANOJ GIRI
# 2  19                                     SMEC      SENTHILKUMAR P
# 3   7                                     SMEC  ARUNA KUMAR BEHURA
# 4  18                                     SMEC    EDWIN SUDHAGAR P
#
#                                              REVIEWS  RATINGS
# 0                                Very chill in class        3
# 1  Very chill in class. You can leave the class a...        3
# 2                                Teaches really well        3
# 3                                           Okay-ish        2
# 4               Chill in class. Teaches really well.        2

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

# %%
df['scores'] = df['REVIEWS'].apply(lambda review: sid.polarity_scores(review))

df['compound']  = df['scores'].apply(lambda score_dict: score_dict['compound'])

df['comp_score'] = df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')

df.head(10)
# Out:
#    Id Which school does the teacher belongs to                  NAME  \
# 0   5                                     SMEC             ANIL P.M.
# 1   6                                     SMEC             ANOJ GIRI
# 2  19                                     SMEC        SENTHILKUMAR P
# 3   7                                     SMEC    ARUNA KUMAR BEHURA
# 4  18                                     SMEC      EDWIN SUDHAGAR P
# 5  21                                     SMEC         THIAGARAJAN S
# 6  23                                     SMEC  BIBHUTI BHUSAN SAHOO
# 7   2                                     SMEC  RAHUL SINGH SIKARWAR
# 8  15                                     SMEC             NAIJU C D
# 9  44                                     SITE      SWARNA PRIYA R.M
#
#                                              REVIEWS  RATINGS  \
# 0                                Very chill in class        3
# 1  Very chill in class. You can leave the class a...        3
# ...

# %%
# Write a review as one continuous string (multiple sentences are ok)
review = 'The teachers is very bad and strict.'

# %%
# Obtain the sid scores for your review
sid.polarity_scores(review)
# Out:
# {'neg': 0.387, 'neu': 0.613, 'pos': 0.0, 'compound': -0.5849}

# %%
review = 'He is very bad in corrction of papers.'

# %%
# Obtain the sid scores for your review
sid.polarity_scores(review)
# Out:
# {'neg': 0.351, 'neu': 0.649, 'pos': 0.0, 'compound': -0.5849}
